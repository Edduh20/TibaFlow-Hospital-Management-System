# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# Load your dataset and explore distributions, correlations, and missing values.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# df = pd.read_csv('../data/raw/your_dataset.csv')
# df.head()
# df.info()
# df.describe()
