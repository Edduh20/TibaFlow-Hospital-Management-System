# %% [markdown]
# # 02 — Feature Engineering
#
# Build and encode features from the cleaned dataset.

# %%
import pandas as pd

# df = pd.read_csv('../data/processed/cleaned.csv')
# Add feature engineering here
