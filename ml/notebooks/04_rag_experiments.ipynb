# %% [markdown]
# # 04 — RAG Experiments
#
# Build and test the Retrieval-Augmented Generation pipeline.

# %%
from src.rag.document_loader import load_pdf, chunk_documents
from src.rag.embeddings import get_huggingface_embeddings
from src.rag.vector_store import build_vector_store, save_vector_store
from src.rag.retriever import get_retriever, similarity_search
from src.rag.chain import get_huggingface_llm, build_rag_chain, query_chain

# %% [markdown]
# ## Step 1 — Load and chunk a document

# %%
# docs = load_pdf('../data/raw/your_document.pdf')
# chunks = chunk_documents(docs, chunk_size=500, chunk_overlap=50)
# print(f'{len(chunks)} chunks created')

# %% [markdown]
# ## Step 2 — Embed and index

# %%
# embeddings = get_huggingface_embeddings()
# vector_store = build_vector_store(chunks, embeddings)
# save_vector_store(vector_store)

# %% [markdown]
# ## Step 3 — Query

# %%
# retriever = get_retriever(vector_store, k=4)
# llm = get_huggingface_llm()
# chain = build_rag_chain(retriever, llm)
# result = query_chain(chain, 'What is this document about?')
# print(result['answer'])
