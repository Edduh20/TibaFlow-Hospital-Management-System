# %% [markdown]
# # 03 — Modeling
#
# Train, tune, and evaluate models.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Load data, train model, evaluate here
